# %% [markdown]
# # Ground Motion Displacement RMS vs Time
#
# *an example simple tutorial for getting seismic data, computing the power spectral densities, extracting the RMS and plotting*
#
# Required:
#
# - python
# - obspy (and its dependencies)
# - pandas
# - jupyter
# - notebook
# - tqdm
#
# this should be easy to set up in a conda env: ``conda create -c conda-forge -n covid python=3.7 obspy pandas jupyter notebook tqdm``
#
# Author: Thomas Lecocq @seismotom, Fred Massin @fmassin, Claudio Satriano @claudiodsf

# %% [markdown]
# ## Step 1: imports

# %%
import datetime
import os
from glob import glob

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42  # to edit text in Illustrator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patheffects as pe
import numpy as np
import pandas as pd
import tqdm
import warnings

from obspy import UTCDateTime, read
from obspy.clients.fdsn import Client
from obspy.clients.fdsn.client import FDSNNoDataException
from obspy.signal import PPSD

# %load_ext autoreload
# %autoreload 2
import seismosocialdistancing_core as seismosocialdistancing

# %% [markdown]
# ## Step 2: Define Start/End dates and Seismic Channel
#
# You'll have to make sure the seed_id you request is indeed available from the ``data_provider``

# %%
## The station information is provided in a file called `seismosocialdistancing_settings.py 

import seismosocialdistancing_settings as ssd

start = ssd.start
end = ssd.end
safety_window = ssd.safety_window

network   = ssd.network
station   = ssd.station
location  = ssd.location
channel   = ssd.channel
dataset   = ssd.dataset
time_zone = ssd.time_zone
sitedesc  = ssd.sitedesc

reference_period=ssd.reference
lockdown_period=ssd.lockdown
reopening_date=ssd.reopening
holiday_period=ssd.summer_hol

data_provider = ssd.data_provider
logo = ssd.logo
bans = ssd.bans

datelist = pd.date_range(start.datetime, min(end, UTCDateTime()).datetime, freq="D")

# This is the current date in pandas format
today = pd.to_datetime(UTCDateTime.now().date)

# %% [markdown]
# ## Step 3: Download the seismic waveform data
#
# This step is coded so that only the last day is redownloaded if the daily files are present on the disk.
#
# The request gets the target day +- 30 minutes to avoid having gaps at the end of each day (need 1 window covering midnight).

# %%
force_reprocess = False

import pathlib
pathlib.Path(os.path.join("..","data")).mkdir(parents=True, exist_ok=True)
pathlib.Path(os.path.join("..","workdir")).mkdir(parents=True, exist_ok=True)


c = Client(data_provider, timeout=10.0)

nslc = "{}.{}.{}.{}".format(network, station, location, channel)
# make sure that wildcard characters are not in nslc
nslc = nslc.replace("*", "").replace("?", "")
pbar = tqdm.tqdm(datelist)
goodday=None

for day in pbar:
    datestr = day.strftime("%Y-%m-%d")
    fn  = os.path.join("..","workdir","{}_{}_{}.mseed".format(dataset, datestr, nslc))
    fnz = os.path.join("..","data","{}_{}_{}.npz".format(dataset, datestr, nslc))
    
    if (today-day > safety_window) and (os.path.isfile(fn) or (os.path.isfile(fnz) and not force_reprocess)):
        pbar.set_description("Using cache - %s" % fn)
        goodday = day
        continue
    else:
        pbar.set_description("Fetching    - %s" % fn)
        try: 
            st = c.get_waveforms(network, station, location, channel,
                                  UTCDateTime(day)-1801, UTCDateTime(day)+86400+1801,
                                  attach_response=True)
            goodday=day
        except FDSNNoDataException:
            print("No data on FDSN server for %s" % fn)
            pbar.set_description("No data on FDSN server for %s" % fn)
            continue
        st.write(fn)

# This is to ensure that we get recent information but allow fallback to earlier dates 

for day in datelist[::-1]:  
    try:
        resp = c.get_stations(UTCDateTime(day), network=network, station=station, location=location,
                      channel=channel, level="response")
        print("Response for date: {}".format(day))
        print(resp)
        break
    except:
        print("Exception for date: {}".format(day))
        pass
# Out:
# Fetching    - ../workdir/AuSiS_Ulladulla_2020-04-16_S1.AUUHS..HHZ.mseed:  26%|██▌       | 121/470 [00:00<00:01, 291.72it/s]
# No data on FDSN server for ../workdir/AuSiS_Ulladulla_2020-01-27_S1.AUUHS..HHZ.mseed
# Fetching    - ../workdir/AuSiS_Ulladulla_2020-04-19_S1.AUUHS..HHZ.mseed:  26%|██▌       | 121/470 [00:00<00:01, 291.72it/s]
# No data on FDSN server for ../workdir/AuSiS_Ulladulla_2020-04-16_S1.AUUHS..HHZ.mseed
# No data on FDSN server for ../workdir/AuSiS_Ulladulla_2020-04-17_S1.AUUHS..HHZ.mseed
# No data on FDSN server for ../workdir/AuSiS_Ulladulla_2020-04-18_S1.AUUHS..HHZ.mseed
# Fetching    - ../workdir/AuSiS_Ulladulla_2020-06-04_S1.AUUHS..HHZ.mseed:  35%|███▌      | 165/470 [00:01<00:02, 149.04it/s]
# No data on FDSN server for ../workdir/AuSiS_Ulladulla_2020-04-19_S1.AUUHS..HHZ.mseed
# Fetching    - ../workdir/AuSiS_Ulladulla_2020-06-07_S1.AUUHS..HHZ.mseed:  35%|███▌      | 165/470 [00:01<00:02, 149.04it/s]
# No data on FDSN server for ../workdir/AuSiS_Ulladulla_2020-06-04_S1.AUUHS..HHZ.mseed
# No data on FDSN server for ../workdir/AuSiS_Ulladulla_2020-06-05_S1.AUUHS..HHZ.mseed
# No data on FDSN server for ../workdir/AuSiS_Ulladulla_2020-06-06_S1.AUUHS..HHZ.mseed
# Using cache - ../workdir/AuSiS_Ulladulla_2020-08-29_S1.AUUHS..HHZ.mseed:  41%|████      | 193/470 [00:01<00:02, 104.69it/s]
# No data on FDSN server for ../workdir/AuSiS_Ulladulla_2020-06-07_S1.AUUHS..HHZ.mseed
# No data on FDSN server for ../workdir/AuSiS_Ulladulla_2020-06-08_S1.AUUHS..HHZ.mseed
# Fetching    - ../workdir/AuSiS_Ulladulla_2021-03-14_S1.AUUHS..HHZ.mseed: 100%|██████████| 470/470 [00:55<00:00,  8.49it/s]
# Response for date: 2021-03-14 00:00:00
# Inventory created at 2021-03-15T10:00:05.732587Z
# 	Sending institution: SeisComP (RSES)
# 	Contains:
# 		Networks (1):
# 			S1
# 		Stations (1):
# 			S1.AUUHS (Ulladulla High School)
# 		Channels (1):
# 			S1.AUUHS..HHZ

# %%
# ls ../data
# Out:
# AuSiS_Ulladulla_2019-12-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-30_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2019-12-31_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-30_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-01-31_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-02-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-30_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-03-31_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-04-30_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-30_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-05-31_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-06-30_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-30_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-07-31_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-30_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-08-31_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-09-30_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-30_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-10-31_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-11-30_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-30_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2020-12-31_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-29_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-30_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-01-31_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-14_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-15_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-16_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-17_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-18_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-19_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-20_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-21_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-22_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-23_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-24_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-25_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-26_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-27_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-02-28_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-01_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-02_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-03_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-04_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-05_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-06_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-07_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-08_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-09_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-10_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-11_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-12_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-13_S1.AUUHS..HHZ.npz
# AuSiS_Ulladulla_2021-03-14_S1.AUUHS..HHZ.npz
# Australia_AUKSC_2020-01-15_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-16_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-17_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-18_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-19_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-20_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-21_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-22_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-23_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-24_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-25_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-26_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-28_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-29_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-30_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-01-31_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-01_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-02_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-03_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-04_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-05_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-06_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-07_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-08_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-10_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-11_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-12_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-13_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-14_S1.AUKSC..BHZ.npz
# Australia_AUKSC_2020-02-15_S1.AUKSC..BHZ.npz

# %%
st = c.get_waveforms(network, station, location, channel,
                                  UTCDateTime(goodday)-1801, UTCDateTime(goodday)+86400+1801,
                                  attach_response=True)

# %% [markdown]
# ## Step 4: Compute PPSDs using custom parameters
#
# These parameters are set to allow the PSDs to be "nervous", not as smooth as the default PQLX ones.

# %%
pbar = tqdm.tqdm(datelist)
for day in pbar:
    datestr = day.strftime("%Y-%m-%d")
    fn_in = os.path.join("..","workdir","{}_{}_{}.mseed".format(dataset, datestr, nslc))
    pbar.set_description("Processing %s" % fn_in)
    if not os.path.isfile(fn_in):
        continue
    stall = read(fn_in, headonly=True)
    for mseedid in list(set([tr.id for tr in stall])):
        fn_out = os.path.join("..","data","{}_{}_{}.npz".format(dataset, datestr, mseedid))
        if (today-day > safety_window) and (os.path.isfile(fn_out) and not force_reprocess):
            continue
        st = read(fn_in, sourcename=mseedid)
        st.attach_response(resp)
        ppsd = PPSD(st[0].stats, metadata=resp,
                    ppsd_length=1800, overlap=0.5,
                    period_smoothing_width_octaves=0.025,
                    period_step_octaves=0.0125,
                    period_limits=(0.008, 50),
                    db_bins=(-200, 20, 0.25))
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            ppsd.add(st)
        ppsd.save_npz(fn_out[:-4])
        del st, ppsd
    del stall
# Out:
# Processing ../workdir/AuSiS_Ulladulla_2021-03-14_S1.AUUHS..HHZ.mseed: 100%|██████████| 470/470 [01:00<00:00,  7.76it/s]

# %% [markdown]
# ## Step 5: Reload daily PSDs from the disk and create a single PPSD object:

# %%
ppsds = {}
pbar = tqdm.tqdm(datelist)
for day in pbar:
    datestr = day.strftime("%Y-%m-%d")
    fn_pattern = os.path.join("..","data","{}_{}_*.npz".format(dataset, datestr))
    pbar.set_description("Reading %s" % fn_pattern)
    for fn in glob(fn_pattern):
        mseedid = fn.replace(".npz", "").split("_")[-1]
        if mseedid not in ppsds:
            ppsds[mseedid] = PPSD.load_npz(fn)#, allow_pickle=True)
        else:
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                ppsds[mseedid].add_npz(fn)#, allow_pickle=True)
# Out:
# Reading ../data/AuSiS_Ulladulla_2021-03-14_*.npz: 100%|██████████| 470/470 [00:12<00:00, 38.21it/s]

# %% [markdown]
# ## Step 6: Standard plots:

# %%
[ppsd.plot(max_percentage=10) for mseedid, ppsd in ppsds.items()]
[ppsd.plot_temporal(0.10) for mseedid, ppsd in ppsds.items()]
[ppsd.plot_spectrogram(clim=(-160,-100)) for mseedid, ppsd in ppsds.items()]
# Out:
# [None]

# %% [markdown]
# ## Step 7: Process PSDs to extract the RMS(displacement)
#
# This can be done for multiple filters at once (``freqs`` below):

# %%
# Define frequency bands of interest:
freqs = [(0.1,1.0),(1.0,20.0),(4.0,14.0),(4.0,20.0)]

displacement_RMS = {}
for mseedid, ppsd in tqdm.tqdm(ppsds.items()):
    ind_times = pd.DatetimeIndex([d.datetime for d in ppsd.current_times_used])
    data = pd.DataFrame(ppsd.psd_values, index=ind_times, columns=1./ppsd.period_bin_centers)
    data = data.sort_index(axis=1)
    displacement_RMS[mseedid] = seismosocialdistancing.df_rms(data, freqs, output="DISP")
    # displacement_RMS[mseedid].to_csv(os.path.join("..", "results", "%s.csv" % mseedid))
    displacement_RMS[mseedid].to_csv(os.path.join("..", "results", "latest.csv"))
# Out:
# 100%|██████████| 1/1 [00:27<00:00, 27.87s/it]

# %% [markdown]
# ## Weekday / Time of day Analysis

# %%
args = {'band':"4.0-14.0",       # might be None or commented ("4.0-14.0" per default) or any of the tupples in freqs
        'time_zone':time_zone,   # required for clockplots
        'sitedesc':sitedesc,     # might be None or commented
        'logo':logo,             # might be None or commented
        'bans':bans,             # might be None or commented
        'save':'../results/',    # might be None or commented or a path 
        'unit':'nm',
        'format':'png',
        'show':True,
        'basename':"../results/latest",      # to over-ride the default name
        'reference_period':reference_period,
        'lockdown_period':lockdown_period,
        'reopening_date':reopening_date,
        'holiday_period':holiday_period
       }

seismosocialdistancing.plot(displacement_RMS,
                            type='timeseries',
                            **args)
# Out:
# /Users/lmoresi/+Github/SeismicNoise_AuSIS_UHS/notebooks/seismosocialdistancing_core.py:747: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   rs = rs.resample("1D" ).median().tshift(12, "H")

# %%
# seismosocialdistancing.plot(displacement_RMS,
#                             type='dailyplots',
#                             **args)

# %%
import seismosocialdistancing_core as seismosocialdistancing

# %%
seismosocialdistancing.plot(displacement_RMS,
                            type='sclockplots',
                            **args)
# Out:
# clock plot - radial scale: 35.11104665716469 nm
# /Users/lmoresi/+Github/SeismicNoise_AuSIS_UHS/notebooks/seismosocialdistancing_core.py:618: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["%.2g %s" %(i,unit) for i in ax.get_yticks()], fontsize=7)
# /Users/lmoresi/+Github/SeismicNoise_AuSIS_UHS/notebooks/seismosocialdistancing_core.py:618: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["%.2g %s" %(i,unit) for i in ax.get_yticks()], fontsize=7)
# /Users/lmoresi/+Github/SeismicNoise_AuSIS_UHS/notebooks/seismosocialdistancing_core.py:618: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["%.2g %s" %(i,unit) for i in ax.get_yticks()], fontsize=7)
# /Users/lmoresi/+Github/SeismicNoise_AuSIS_UHS/notebooks/seismosocialdistancing_core.py:618: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["%.2g %s" %(i,unit) for i in ax.get_yticks()], fontsize=7)

# %% [markdown]
# ## Noise distribution over time of the day

# %%
# seismosocialdistancing.plot(displacement_RMS,
#                             type='clockmaps',
#                             **args)

# %%
seismosocialdistancing.plot(displacement_RMS,
                            type='gridmaps',
                            **args)

# %% [markdown]
# ## Temporary code: All your stations' colormapped plot

# %%
normalize = True
resample_freq = "1H"
clip = (0.05,0.95)

#concatenating in a single dataframe and converting to nm
dRMS2D = pd.concat(displacement_RMS, axis=0) * 1e9
for band in dRMS2D.columns:
    g = dRMS2D.loc[:,band].unstack().T
    g = g.clip(g.quantile(clip[0]),g.quantile(clip[1]),axis=1)
    g = g.resample(resample_freq).median()
    if normalize:
        g -= g.quantile(0.01)
        g /= g.quantile(0.99)
        vmin, vmax = 0, 1
    else:
        vmin = vmax = None
   
    fig, ax = plt.subplots(1,1, figsize=(12,2*len(g.columns)))
    label = '%sDisplacement (µm)' % ["","Normalized "][normalize]

    x = np.append(g.index.values, g.index.shift(1).values[-1])
    y = np.append(g.columns, "")
    plt.pcolormesh(x, y, g.T,  cmap="inferno", vmin=vmin, vmax=vmax)
    plt.colorbar(orientation='horizontal', shrink=0.3).set_label(label)
    pos, l = plt.yticks()
    plt.yticks(np.asarray(pos)+0.5, y)
    plt.margins(0)
    plt.title("%s Hz" % band)
    plt.gca().invert_yaxis()
    plt.show()
